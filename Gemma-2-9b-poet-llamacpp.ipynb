# %%
# !pip install llama-cpp-python \
  --extra-index-url https://abetlen.github.io/llama-cpp-python/whl/cu122
# Out:
# Looking in indexes: https://pypi.org/simple, https://abetlen.github.io/llama-cpp-python/whl/cu122
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.9/63.9 MB 6.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.9 MB/s eta 0:00:00
# ...
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.3.1-cp310-cp310-linux_x86_64.whl size=3485357 sha256=23b6360f8a41f6690af5dedbe0d357d6fd70b7a8b46abbf1e7c885d8e8975128
#   Stored in directory: /root/.cache/pip/wheels/f8/b0/a2/f47d952aec7ab061b9e2a345e23a1e1e137beb7891259e3d0c
# Successfully built llama-cpp-python
# ...

# %%
from huggingface_hub import hf_hub_download
from llama_cpp import Llama

model_name = "leinadsened/Gemma-2-9b-hun-poet"
model_file = "unsloth.Q8_0.gguf"
model_path = hf_hub_download(model_name,
                             filename=model_file,
                             local_dir=''
)
llm = Llama(model_path=model_path,
            n_gpu_layers=-1)
# Out:
# unsloth.Q8_0.gguf:   0%|          | 0.00/9.83G [00:00<?, ?B/s]
# My model path:  unsloth.Q8_0.gguf

# %%
chat = """Below is a hungarian poet's name, you need to write a poem in their style. Instructions provide additional details about the poem.

### Poet:
Petőfi Sándor

### Instruction:
Írj egy verset anyáink tyúkjairól, akik gilisztákat kergetnek. Legyen a vers térfás hangulatú. Szerepeljen benne Csenge.

### Response:
{}"""
response = llm(chat, max_tokens=256)
print(response["choices"][0][text])
# Out:
# Llama.generate: 57 prefix-match hit, remaining 36 prompt tokens to eval
# llama_perf_context_print:        load time =   55675.66 ms
# llama_perf_context_print: prompt eval time =       0.00 ms /    36 tokens (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:        eval time =       0.00 ms /   166 runs   (    0.00 ms per token,      inf tokens per second)
# llama_perf_context_print:       total time =  311282.62 ms /   202 tokens
# {'id': 'cmpl-23d3cfcc-7e13-4e99-ac17-e1538fa83ca2',
#  'object': 'text_completion',
#  'created': 1730723009,
#  'model': 'unsloth.Q8_0.gguf',
# ...
